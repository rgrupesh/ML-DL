# %%
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-5ab7e91c-dc07-4365-a312-c74caeeaa0ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ab7e91c-dc07-4365-a312-c74caeeaa0ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 67 bytes

# %%
# !kaggle competitions download -c rfcx-species-audio-detection
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading 03-63.tfrec.zip to /content
#  96% 263M/274M [00:01<00:00, 164MB/s]
# 100% 274M/274M [00:01<00:00, 145MB/s]
# Downloading 17-63.tfrec.zip to /content
#  98% 266M/270M [00:01<00:00, 163MB/s]
# 100% 270M/270M [00:01<00:00, 143MB/s]
# Downloading 12-63.tfrec.zip to /content
#  96% 257M/269M [00:02<00:00, 158MB/s]
# 100% 269M/269M [00:02<00:00, 132MB/s]
# Downloading 19-63.tfrec.zip to /content
#  99% 265M/269M [00:02<00:00, 170MB/s]
# 100% 269M/269M [00:02<00:00, 129MB/s]
# Downloading 13-63.tfrec.zip to /content
#  98% 265M/270M [00:02<00:00, 117MB/s]
# 100% 270M/270M [00:02<00:00, 123MB/s]
# Downloading 15-63.tfrec.zip to /content
#  96% 263M/274M [00:02<00:00, 138MB/s]
# 100% 274M/274M [00:02<00:00, 126MB/s]
# Downloading 04-63.tfrec.zip to /content
#  95% 265M/279M [00:01<00:00, 181MB/s]
# 100% 279M/279M [00:01<00:00, 151MB/s]
# Downloading 07-63.tfrec.zip to /content
# 100% 270M/271M [00:05<00:00, 41.0MB/s]
# 100% 271M/271M [00:05<00:00, 55.2MB/s]
# Downloading 09-63.tfrec.zip to /content
#  99% 265M/268M [00:07<00:00, 29.8MB/s]
# 100% 268M/268M [00:07<00:00, 36.3MB/s]
# Downloading 06-63.tfrec.zip to /content
#  99% 274M/277M [00:07<00:00, 32.0MB/s]
# 100% 277M/277M [00:07<00:00, 40.6MB/s]
# Downloading 05-63.tfrec.zip to /content
# 100% 275M/275M [00:03<00:00, 54.2MB/s]
#
# Downloading 14-63.tfrec.zip to /content
#  99% 264M/266M [00:08<00:00, 26.4MB/s]
# 100% 266M/266M [00:08<00:00, 32.4MB/s]
# Downloading 08-63.tfrec.zip to /content
#  99% 265M/268M [00:05<00:00, 48.4MB/s]
# 100% 268M/268M [00:05<00:00, 51.1MB/s]
# Downloading 18-63.tfrec.zip to /content
#  99% 267M/270M [00:06<00:00, 44.7MB/s]
# 100% 270M/270M [00:07<00:00, 40.1MB/s]
# Downloading 01-63.tfrec.zip to /content
# 100% 270M/270M [00:06<00:00, 37.9MB/s]
#
# Downloading 10-63.tfrec.zip to /content
#  98% 264M/268M [00:08<00:00, 12.5MB/s]
# 100% 268M/268M [00:08<00:00, 33.8MB/s]
# Downloading 16-63.tfrec.zip to /content
#  95% 256M/269M [00:02<00:00, 69.0MB/s]
# 100% 269M/269M [00:02<00:00, 107MB/s]
# Downloading 00-63.tfrec.zip to /content
#  99% 267M/270M [00:07<00:00, 37.5MB/s]
# 100% 270M/270M [00:07<00:00, 38.5MB/s]
# Downloading 11-63.tfrec.zip to /content
#  98% 266M/271M [00:06<00:00, 37.8MB/s]
# 100% 271M/271M [00:06<00:00, 42.8MB/s]
# Downloading 02-63.tfrec.zip to /content
# 100% 271M/272M [00:06<00:00, 27.8MB/s]
# 100% 272M/272M [00:06<00:00, 44.5MB/s]
# Downloading 11-148.tfrec.zip to /content
#  98% 632M/644M [00:15<00:00, 30.9MB/s]
# 100% 644M/644M [00:15<00:00, 43.6MB/s]
# Downloading 10-148.tfrec.zip to /content
# 100% 636M/636M [00:15<00:00, 14.8MB/s]
#
# Downloading 09-148.tfrec.zip to /content
# 100% 639M/639M [00:15<00:00, 49.3MB/s]
#
# Downloading 05-148.tfrec.zip to /content
#  99% 647M/651M [00:17<00:00, 68.6MB/s]
# 100% 651M/651M [00:18<00:00, 37.9MB/s]
# Downloading 03-148.tfrec.zip to /content
# 100% 645M/647M [00:12<00:00, 33.5MB/s]
# 100% 647M/647M [00:12<00:00, 53.0MB/s]
# Downloading 14-148.tfrec.zip to /content
#  99% 633M/636M [00:17<00:00, 30.4MB/s]
# 100% 636M/636M [00:18<00:00, 37.1MB/s]
# Downloading 13-148.tfrec.zip to /content
#  98% 627M/640M [00:12<00:01, 8.12MB/s]
# 100% 640M/640M [00:12<00:00, 54.9MB/s]
# Downloading 00-148.tfrec.zip to /content
#  99% 641M/648M [00:17<00:00, 64.0MB/s]
# 100% 648M/648M [00:17<00:00, 38.1MB/s]
# Downloading 19-148.tfrec.zip to /content
# 100% 635M/635M [00:13<00:00, 27.3MB/s]
#
# Downloading 15-148.tfrec.zip to /content
# 100% 633M/636M [00:15<00:00, 43.3MB/s]
# 100% 636M/636M [00:15<00:00, 44.0MB/s]
# Downloading 17-148.tfrec.zip to /content
#  99% 633M/640M [00:13<00:00, 67.0MB/s]
# 100% 640M/640M [00:14<00:00, 47.6MB/s]
# Downloading 07-148.tfrec.zip to /content
# 100% 652M/652M [00:16<00:00, 53.6MB/s]
#
# Downloading 01-148.tfrec.zip to /content
#  98% 633M/644M [00:15<00:00, 34.1MB/s]
# 100% 644M/644M [00:15<00:00, 44.4MB/s]
# Downloading 04-148.tfrec.zip to /content
#  99% 646M/649M [00:15<00:00, 43.2MB/s]
# 100% 649M/649M [00:15<00:00, 43.9MB/s]
# Downloading 08-148.tfrec.zip to /content
# 100% 650M/651M [00:15<00:00, 51.5MB/s]
# 100% 651M/651M [00:15<00:00, 43.2MB/s]
# Downloading 16-148.tfrec.zip to /content
#  99% 632M/636M [00:14<00:00, 59.6MB/s]
# 100% 636M/636M [00:14<00:00, 45.4MB/s]
# Downloading 02-148.tfrec.zip to /content
# 100% 649M/650M [00:15<00:00, 36.1MB/s]
# 100% 650M/650M [00:15<00:00, 43.9MB/s]
# Downloading 18-148.tfrec.zip to /content
# 100% 642M/644M [00:15<00:00, 42.1MB/s]
# 100% 644M/644M [00:15<00:00, 42.6MB/s]
# Downloading 12-148.tfrec.zip to /content
# 100% 642M/643M [00:12<00:00, 85.8MB/s]
# 100% 643M/643M [00:12<00:00, 53.1MB/s]
# Downloading 06-148.tfrec.zip to /content
#  99% 637M/641M [00:05<00:00, 100MB/s]
# 100% 641M/641M [00:05<00:00, 119MB/s]
# Downloading 01d36def5.flac.zip to /content
#   0% 0.00/3.20M [00:00<?, ?B/s]
# 100% 3.20M/3.20M [00:00<00:00, 105MB/s]
# Downloading 0061c037e.flac.zip to /content
#   0% 0.00/3.22M [00:00<?, ?B/s]
# 100% 3.22M/3.22M [00:00<00:00, 102MB/s]
# Downloading 013bd8b85.flac.zip to /content
#   0% 0.00/3.42M [00:00<?, ?B/s]
# 100% 3.42M/3.42M [00:00<00:00, 97.6MB/s]
# Downloading 0208fec47.flac.zip to /content
#   0% 0.00/3.03M [00:00<?, ?B/s]
# 100% 3.03M/3.03M [00:00<00:00, 99.1MB/s]
# Downloading 01bd97dd6.flac.zip to /content
#   0% 0.00/2.92M [00:00<?, ?B/s]
# 100% 2.92M/2.92M [00:00<00:00, 94.1MB/s]
# Downloading 01fefebcb.flac.zip to /content
#   0% 0.00/3.01M [00:00<?, ?B/s]
# 100% 3.01M/3.01M [00:00<00:00, 86.0MB/s]
# Downloading 010eb14d3.flac.zip to /content
#   0% 0.00/3.48M [00:00<?, ?B/s]
# 100% 3.48M/3.48M [00:00<00:00, 87.3MB/s]
# Downloading 01812f522.flac.zip to /content
#   0% 0.00/3.51M [00:00<?, ?B/s]
# 100% 3.51M/3.51M [00:00<00:00, 114MB/s]
# Downloading 02c30604d.flac.zip to /content
#   0% 0.00/3.27M [00:00<?, ?B/s]
# 100% 3.27M/3.27M [00:00<00:00, 107MB/s]
# Downloading 039395460.flac.zip to /content
#   0% 0.00/3.31M [00:00<?, ?B/s]
# 100% 3.31M/3.31M [00:00<00:00, 105MB/s]
# Downloading 0232841d4.flac.zip to /content
#   0% 0.00/3.39M [00:00<?, ?B/s]
# 100% 3.39M/3.39M [00:00<00:00, 77.1MB/s]
# Downloading 019db5220.flac.zip to /content
#   0% 0.00/2.97M [00:00<?, ?B/s]
# 100% 2.97M/2.97M [00:00<00:00, 97.9MB/s]
# Downloading 01307e693.flac.zip to /content
#   0% 0.00/3.35M [00:00<?, ?B/s]
# 100% 3.35M/3.35M [00:00<00:00, 109MB/s]
# Downloading 000316da7.flac.zip to /content
#   0% 0.00/3.10M [00:00<?, ?B/s]
# 100% 3.10M/3.10M [00:00<00:00, 101MB/s]
# Downloading 037460d90.flac.zip to /content
#   0% 0.00/3.49M [00:00<?, ?B/s]
# 100% 3.49M/3.49M [00:00<00:00, 113MB/s]
# Downloading 011318064.flac.zip to /content
#   0% 0.00/3.15M [00:00<?, ?B/s]
# 100% 3.15M/3.15M [00:00<00:00, 104MB/s]
# Downloading 0303dee3c.flac.zip to /content
#   0% 0.00/3.42M [00:00<?, ?B/s]
# 100% 3.42M/3.42M [00:00<00:00, 112MB/s]
# Downloading 003bc2cb2.flac.zip to /content
#   0% 0.00/3.35M [00:00<?, ?B/s]
# 100% 3.35M/3.35M [00:00<00:00, 104MB/s]
# Downloading 034f46152.flac.zip to /content
#   0% 0.00/2.84M [00:00<?, ?B/s]
# 100% 2.84M/2.84M [00:00<00:00, 144MB/s]
# Downloading 02dbcc383.flac.zip to /content
#   0% 0.00/3.59M [00:00<?, ?B/s]
# 100% 3.59M/3.59M [00:00<00:00, 118MB/s]
# Downloading 0079ff47b.flac.zip to /content
#   0% 0.00/3.29M [00:00<?, ?B/s]
# 100% 3.29M/3.29M [00:00<00:00, 109MB/s]
# Downloading 009b760e6.flac.zip to /content
#   0% 0.00/3.17M [00:00<?, ?B/s]
# 100% 3.17M/3.17M [00:00<00:00, 104MB/s]
# Downloading 003bec244.flac.zip to /content
#   0% 0.00/3.27M [00:00<?, ?B/s]
# 100% 3.27M/3.27M [00:00<00:00, 108MB/s]
# Downloading 009aa1c8f.flac.zip to /content
#   0% 0.00/3.20M [00:00<?, ?B/s]
# 100% 3.20M/3.20M [00:00<00:00, 105MB/s]
# Downloading 003b04435.flac.zip to /content
#   0% 0.00/3.42M [00:00<?, ?B/s]
# 100% 3.42M/3.42M [00:00<00:00, 92.7MB/s]
# Downloading 0099c367b.flac.zip to /content
#   0% 0.00/2.99M [00:00<?, ?B/s]
# 100% 2.99M/2.99M [00:00<00:00, 68.7MB/s]
# Downloading 011f25080.flac.zip to /content
#   0% 0.00/3.45M [00:00<?, ?B/s]
# 100% 3.45M/3.45M [00:00<00:00, 113MB/s]
# Downloading 00f3b3c1e.flac.zip to /content
#   0% 0.00/3.14M [00:00<?, ?B/s]
# 100% 3.14M/3.14M [00:00<00:00, 127MB/s]
# Downloading 00b404881.flac.zip to /content
#   0% 0.00/3.52M [00:00<?, ?B/s]
# 100% 3.52M/3.52M [00:00<00:00, 144MB/s]
# Downloading 00204008d.flac.zip to /content
#   0% 0.00/3.06M [00:00<?, ?B/s]
# 100% 3.06M/3.06M [00:00<00:00, 101MB/s]
# Downloading 007f87ba2.flac.zip to /content
#   0% 0.00/3.39M [00:00<?, ?B/s]
# 100% 3.39M/3.39M [00:00<00:00, 111MB/s]
# Downloading 0072f0839.flac.zip to /content
#   0% 0.00/2.90M [00:00<?, ?B/s]
# 100% 2.90M/2.90M [00:00<00:00, 97.5MB/s]
# Downloading 00ad36516.flac.zip to /content
#   0% 0.00/3.45M [00:00<?, ?B/s]
# 100% 3.45M/3.45M [00:00<00:00, 114MB/s]
# Downloading 008c9c381.flac.zip to /content
#   0% 0.00/4.47M [00:00<?, ?B/s]
# 100% 4.47M/4.47M [00:00<00:00, 41.0MB/s]
# Downloading 005f1f9a5.flac.zip to /content
#   0% 0.00/3.35M [00:00<?, ?B/s]
# 100% 3.35M/3.35M [00:00<00:00, 170MB/s]
# Downloading 009fbc7b4.flac.zip to /content
#   0% 0.00/3.32M [00:00<?, ?B/s]
# 100% 3.32M/3.32M [00:00<00:00, 96.8MB/s]
# Downloading 00e3525a2.flac.zip to /content
#   0% 0.00/3.05M [00:00<?, ?B/s]
# 100% 3.05M/3.05M [00:00<00:00, 171MB/s]
# Downloading 006ab765f.flac.zip to /content
#   0% 0.00/2.88M [00:00<?, ?B/s]
# 100% 2.88M/2.88M [00:00<00:00, 163MB/s]
# Downloading 00d442df7.flac.zip to /content
#   0% 0.00/3.22M [00:00<?, ?B/s]
# 100% 3.22M/3.22M [00:00<00:00, 97.8MB/s]
# Downloading 00834f88e.flac.zip to /content
#   0% 0.00/3.31M [00:00<?, ?B/s]
# 100% 3.31M/3.31M [00:00<00:00, 108MB/s]
# Downloading train_tp.csv to /content
#   0% 0.00/52.9k [00:00<?, ?B/s]
# 100% 52.9k/52.9k [00:00<00:00, 55.5MB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/206k [00:00<?, ?B/s]
# 100% 206k/206k [00:00<00:00, 66.0MB/s]
# Downloading train_fp.csv to /content
#   0% 0.00/344k [00:00<?, ?B/s]
# 100% 344k/344k [00:00<00:00, 104MB/s]

# %%
ls
# Out:
# 000316da7.flac.zip  01307e693.flac.zip  08-148.tfrec.zip
# 00-148.tfrec.zip    013bd8b85.flac.zip  08-63.tfrec.zip
# 00204008d.flac.zip  01-63.tfrec.zip     09-148.tfrec.zip
# 003b04435.flac.zip  01812f522.flac.zip  09-63.tfrec.zip
# 003bc2cb2.flac.zip  019db5220.flac.zip  10-148.tfrec.zip
# 003bec244.flac.zip  01bd97dd6.flac.zip  10-63.tfrec.zip
# 005f1f9a5.flac.zip  01d36def5.flac.zip  11-148.tfrec.zip
# 0061c037e.flac.zip  01fefebcb.flac.zip  11-63.tfrec.zip
# 00-63.tfrec.zip     0208fec47.flac.zip  12-148.tfrec.zip
# 006ab765f.flac.zip  02-148.tfrec.zip    12-63.tfrec.zip
# 0072f0839.flac.zip  0232841d4.flac.zip  13-148.tfrec.zip
# 0079ff47b.flac.zip  02-63.tfrec.zip     13-63.tfrec.zip
# 007f87ba2.flac.zip  02c30604d.flac.zip  14-148.tfrec.zip
# 00834f88e.flac.zip  02dbcc383.flac.zip  14-63.tfrec.zip
# 008c9c381.flac.zip  0303dee3c.flac.zip  15-148.tfrec.zip
# 0099c367b.flac.zip  03-148.tfrec.zip    15-63.tfrec.zip
# 009aa1c8f.flac.zip  034f46152.flac.zip  16-148.tfrec.zip
# 009b760e6.flac.zip  03-63.tfrec.zip     16-63.tfrec.zip
# 009fbc7b4.flac.zip  037460d90.flac.zip  17-148.tfrec.zip
# 00ad36516.flac.zip  039395460.flac.zip  17-63.tfrec.zip
# 00b404881.flac.zip  04-148.tfrec.zip    18-148.tfrec.zip
# 00d442df7.flac.zip  04-63.tfrec.zip     18-63.tfrec.zip
# 00e3525a2.flac.zip  05-148.tfrec.zip    19-148.tfrec.zip
# 00f3b3c1e.flac.zip  05-63.tfrec.zip     19-63.tfrec.zip
# 010eb14d3.flac.zip  06-148.tfrec.zip    sample_data/
# 011318064.flac.zip  06-63.tfrec.zip     sample_submission.csv
# 01-148.tfrec.zip    07-148.tfrec.zip    train_fp.csv
# 011f25080.flac.zip  07-63.tfrec.zip     train_tp.csv

# %%
df = pd.read_csv("train_fp.csv")

# %%
df.head()
# Out:
#   recording_id  species_id  songtype_id  ...       f_min    t_max       f_max
# 0    00204008d          21            1  ...   3281.2500  14.9333   4125.0000
# 1    00204008d           8            1  ...   3750.0000  28.6187   5531.2500
# 2    00204008d           4            1  ...   2343.7500  16.8587   4218.7500
# 3    003b04435          22            1  ...  10687.5000  44.8587  13687.5000
# 4    003b04435          23            1  ...   7235.1562  15.2091  11283.3984
#
# [5 rows x 7 columns]
